# %%
import pandas as pd
import os
import glob

finance_data_dir = r"D:\CnnTA\v2\data_finance\train\1d"
sentiment_data_dir = r"D:\CnnTA\v2\data_sentim\train"

data_dirs = [finance_data_dir, sentiment_data_dir]

# %%
finance_symbols = []
sentiment_companies = []
all_csv_files = []

for data_dir in data_dirs:
    csv_files = glob.glob(os.path.join(data_dir, "*.csv"))
    all_csv_files.extend(csv_files)
    for file in csv_files:
        filename = os.path.basename(file)
        parts = filename.split('_')
        if filename.startswith('gdelt_'):
            # Sentiment: gdelt_company_...csv
            # Try to extract company name between 'gdelt_' and the last date part
            if len(parts) > 2:
                company = '_'.join(parts[1:-4]) if len(parts) > 5 else parts[1]
            else:
                company = parts[1] if len(parts) > 1 else ''
            sentiment_companies.append(company)
        else:
            # Finance: SYMBOL_...csv
            symbol = parts[0]
            finance_symbols.append(symbol)

print("Finance symbols:", set(finance_symbols))
print("Sentiment companies:", set(sentiment_companies))
# Out:
# Finance symbols: {'HD', 'PG', 'TRV', 'MCD', 'MSFT', 'MRK', 'VZ', 'GE', 'AXP', 'V', 'DD', 'CVX', 'DIS', 'GS', 'IBM', 'XOM', 'INTC', 'PFE', 'BA', 'AAPL', 'CSCO', 'JPM', 'KO', 'UNH', 'JNJ', 'NKE', 'CAT', 'MMM', 'WMT'}
# Sentiment companies: {'travelers', 'boeing', 'chevron', 'apple', 'microsoft', 'ibm', 'nvidia', 'salesforce', 'nike', '3m', 'disney', 'cisco', 'honeywell', 'amazon', 'verizon', 'jpmorgan', 'american', 'caterpillar', "mcdonald's", 'visa', 'unitedhealth', 'goldman', 'home', 'walmart', 'amgen'}

# %%
# Mapping finance symbols to sentiment companies (where possible)
finance_to_sentiment = {
    'AAPL': 'apple',
    'AXP': 'american',
    'BA': 'boeing',
    'CAT': 'caterpillar',
    'CSCO': 'cisco',
    'CVX': 'chevron',
    'DIS': 'disney',
    'GS': 'goldman',
    'HD': 'home',
    'IBM': 'ibm',
    'JPM': 'jpmorgan',
    'MCD': "mcdonald's",
    'MMM': '3m',
    'MSFT': 'microsoft',
    'NKE': 'nike',
    'TRV': 'travelers',
    'UNH': 'unitedhealth',
    'V': 'visa',
    'VZ': 'verizon',
    'WMT': 'walmart',
}

# Reverse mapping: sentiment company to finance symbol (where possible)
sentiment_to_finance = {v: k for k, v in finance_to_sentiment.items() if v is not None}

# %%
for symbol in finance_symbols:
    # Find corresponding sentiment company name
    sentiment_company = finance_to_sentiment.get(symbol)
    if not sentiment_company:
        print(f"{symbol}: No sentiment mapping.")
        continue

    # Find finance file
    finance_file = None
    for f in all_csv_files:
        if os.path.basename(f).startswith(symbol + "_"):
            finance_file = f
            break
    if not finance_file:
        print(f"{symbol}: Finance file not found.")
        continue

    # Find sentiment file
    sentiment_file = None
    for f in all_csv_files:
        if os.path.basename(f).startswith(f"gdelt_{sentiment_company}_"):
            sentiment_file = f
            break
    if not sentiment_file:
        print(f"{symbol}: Sentiment file not found for {sentiment_company}.")
        continue

    # Read both files
    try:
        df_fin = pd.read_csv(finance_file)
        df_sent = pd.read_csv(sentiment_file)
    except Exception as e:
        print(f"{symbol}: Error reading files: {e}")
        continue

    # Try to find the date column (case-insensitive)
    fin_date_col = next((col for col in df_fin.columns if col.lower() == "date"), None)
    sent_date_col = next((col for col in df_sent.columns if col.lower() == "date"), None)

    if not fin_date_col or not sent_date_col:
        print(f"{symbol}: Date column not found in one of the files.")
        continue

    # Convert to datetime, handling Unix ms timestamps
    def parse_dates(series):
        # If all values are numbers or digit strings, treat as ms since epoch
        if pd.api.types.is_numeric_dtype(series) or series.astype(str).str.isdigit().all():
            return pd.to_datetime(series, unit='ms')
        else:
            return pd.to_datetime(series)

    try:
        fin_dates = parse_dates(df_fin[fin_date_col])
        sent_dates = parse_dates(df_sent[sent_date_col])
    except Exception as e:
        print(f"{symbol}: Error parsing dates: {e}")
        continue

    print(f"{symbol} ({sentiment_company}):")
    print(f"  Finance date range:  {fin_dates.min()}  to  {fin_dates.max()}")
    print(f"  Sentiment date range: {sent_dates.min()}  to  {sent_dates.max()}")
# Out:
# AAPL (apple):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-03-01 00:00:00  to  2022-12-31 00:00:00
# AXP (american):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-02-01 00:00:00  to  2022-12-31 00:00:00
# BA (boeing):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-01-13 00:00:00  to  2022-12-31 00:00:00
# CAT (caterpillar):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-02-06 00:00:00  to  2022-12-31 00:00:00
# CSCO (cisco):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-09-21 00:00:00  to  2022-12-31 00:00:00
# CVX (chevron):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-02-08 00:00:00  to  2022-12-31 00:00:00
# DD: No sentiment mapping.
# DIS (disney):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-01-12 00:00:00  to  2022-12-31 00:00:00
# GE: No sentiment mapping.
# GS (goldman):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-02-08 00:00:00  to  2022-08-02 00:00:00
# HD (home):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-02-14 00:00:00  to  2022-12-31 00:00:00
# IBM (ibm):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-01-04 00:00:00  to  2022-12-31 00:00:00
# INTC: No sentiment mapping.
# JNJ: No sentiment mapping.
# JPM (jpmorgan):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-02-08 00:00:00  to  2022-12-31 00:00:00
# KO: No sentiment mapping.
# MCD (mcdonald's):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-01-17 00:00:00  to  2022-12-31 00:00:00
# MMM (3m):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-03-09 00:00:00  to  2022-12-31 00:00:00
# MRK: No sentiment mapping.
# MSFT (microsoft):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-02-14 00:00:00  to  2022-12-31 00:00:00
# NKE (nike):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-01-19 00:00:00  to  2022-12-31 00:00:00
# PFE: No sentiment mapping.
# PG: No sentiment mapping.
# TRV (travelers):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-03-21 00:00:00  to  2022-12-31 00:00:00
# UNH (unitedhealth):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-02-17 00:00:00  to  2022-12-31 00:00:00
# VZ (verizon):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-01-26 00:00:00  to  2022-12-31 00:00:00
# V (visa):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-01-16 00:00:00  to  2022-12-31 00:00:00
# WMT (walmart):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-01-07 00:00:00  to  2022-12-31 00:00:00
# XOM: No sentiment mapping.
# NKE (nike):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-01-19 00:00:00  to  2022-12-31 00:00:00
# PFE: No sentiment mapping.
# PG: No sentiment mapping.
# TRV (travelers):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-03-21 00:00:00  to  2022-12-31 00:00:00
# UNH (unitedhealth):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-02-17 00:00:00  to  2022-12-31 00:00:00
# VZ (verizon):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-01-26 00:00:00  to  2022-12-31 00:00:00
# V (visa):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-01-16 00:00:00  to  2022-12-31 00:00:00
# WMT (walmart):
#   Finance date range:  2017-01-03 00:00:00  to  2022-12-30 00:00:00
#   Sentiment date range: 2017-01-07 00:00:00  to  2022-12-31 00:00:00
# XOM: No sentiment mapping.

# %%
# Check alignment between finance and sentiment CSVs for each symbol
for symbol in finance_symbols:
    sentiment_company = finance_to_sentiment.get(symbol)
    if not sentiment_company:
        continue

    # Find finance and sentiment files
    finance_file = None
    sentiment_file = None
    for f in all_csv_files:
        if os.path.basename(f).startswith(symbol + "_"):
            finance_file = f
        if os.path.basename(f).startswith(f"gdelt_{sentiment_company}_"):
            sentiment_file = f
    if not finance_file or not sentiment_file:
        continue

    try:
        df_fin = pd.read_csv(finance_file)
        df_sent = pd.read_csv(sentiment_file)
    except Exception as e:
        print(f"{symbol}: Error reading files: {e}")
        continue

    # Find date columns
    fin_date_col = next((col for col in df_fin.columns if col.lower() == "date"), None)
    sent_date_col = next((col for col in df_sent.columns if col.lower() == "date"), None)
    if not fin_date_col or not sent_date_col:
        print(f"{symbol}: Date column not found.")
        continue

    # Parse dates
    def parse_dates(series):
        if pd.api.types.is_numeric_dtype(series) or series.astype(str).str.isdigit().all():
            return pd.to_datetime(series, unit='ms')
        else:
            return pd.to_datetime(series)
    try:
        fin_dates = parse_dates(df_fin[fin_date_col])
        sent_dates = parse_dates(df_sent[sent_date_col])
    except Exception as e:
        print(f"{symbol}: Error parsing dates: {e}")
        continue

    # Set as index for fast lookup
    fin_dates_set = set(fin_dates.dt.normalize())
    sent_dates_set = set(sent_dates.dt.normalize())

    missing_in_sent = fin_dates_set - sent_dates_set
    extra_in_sent = sent_dates_set - fin_dates_set

    print(f"\n{symbol} ({sentiment_company}):")
    print(f"  Finance rows: {len(fin_dates_set)}")
    print(f"  Sentiment rows: {len(sent_dates_set)}")
    print(f"  Days in finance but missing in sentiment: {len(missing_in_sent)}")
    if missing_in_sent:
        print(f"    Missing days: {sorted(list(missing_in_sent))[:10]}{' ...' if len(missing_in_sent)>10 else ''}")
    print(f"  Days in sentiment but not in finance: {len(extra_in_sent)}")
    if extra_in_sent:
        print(f"    Extra days: {sorted(list(extra_in_sent))[:10]}{' ...' if len(extra_in_sent)>10 else ''}")
    print(f"  Overlap days: {len(fin_dates_set & sent_dates_set)}")
# Out:
# AAPL (apple):
#   Finance rows: 1510
#   Sentiment rows: 2132
#   Days in finance but missing in sentiment: 39
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 661
#     Extra days: [Timestamp('2017-03-04 00:00:00'), Timestamp('2017-03-05 00:00:00'), Timestamp('2017-03-11 00:00:00'), Timestamp('2017-03-12 00:00:00'), Timestamp('2017-03-18 00:00:00'), Timestamp('2017-03-19 00:00:00'), Timestamp('2017-03-25 00:00:00'), Timestamp('2017-03-26 00:00:00'), Timestamp('2017-04-01 00:00:00'), Timestamp('2017-04-02 00:00:00')] ...
#   Overlap days: 1471
#
# AXP (american):
#   Finance rows: 1510
#   Sentiment rows: 2160
#   Days in finance but missing in sentiment: 20
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 670
#     Extra days: [Timestamp('2017-02-04 00:00:00'), Timestamp('2017-02-05 00:00:00'), Timestamp('2017-02-11 00:00:00'), Timestamp('2017-02-12 00:00:00'), Timestamp('2017-02-18 00:00:00'), Timestamp('2017-02-19 00:00:00'), Timestamp('2017-02-20 00:00:00'), Timestamp('2017-02-25 00:00:00'), Timestamp('2017-02-26 00:00:00'), Timestamp('2017-03-04 00:00:00')] ...
#   Overlap days: 1490
#
# BA (boeing):
#   Finance rows: 1510
#   Sentiment rows: 2179
#   Days in finance but missing in sentiment: 8
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00')]
#   Days in sentiment but not in finance: 677
#     Extra days: [Timestamp('2017-01-14 00:00:00'), Timestamp('2017-01-15 00:00:00'), Timestamp('2017-01-16 00:00:00'), Timestamp('2017-01-21 00:00:00'), Timestamp('2017-01-22 00:00:00'), Timestamp('2017-01-28 00:00:00'), Timestamp('2017-01-29 00:00:00'), Timestamp('2017-02-04 00:00:00'), Timestamp('2017-02-05 00:00:00'), Timestamp('2017-02-11 00:00:00')] ...
#   Overlap days: 1502
#
# CAT (caterpillar):
#   Finance rows: 1510
#   Sentiment rows: 2155
#   Days in finance but missing in sentiment: 23
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 668
#     Extra days: [Timestamp('2017-02-11 00:00:00'), Timestamp('2017-02-12 00:00:00'), Timestamp('2017-02-18 00:00:00'), Timestamp('2017-02-19 00:00:00'), Timestamp('2017-02-20 00:00:00'), Timestamp('2017-02-25 00:00:00'), Timestamp('2017-02-26 00:00:00'), Timestamp('2017-03-04 00:00:00'), Timestamp('2017-03-05 00:00:00'), Timestamp('2017-03-11 00:00:00')] ...
#   Overlap days: 1487
#
# CSCO (cisco):
#   Finance rows: 1510
#   Sentiment rows: 1928
#   Days in finance but missing in sentiment: 181
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 599
#     Extra days: [Timestamp('2017-09-23 00:00:00'), Timestamp('2017-09-24 00:00:00'), Timestamp('2017-09-30 00:00:00'), Timestamp('2017-10-01 00:00:00'), Timestamp('2017-10-07 00:00:00'), Timestamp('2017-10-08 00:00:00'), Timestamp('2017-10-14 00:00:00'), Timestamp('2017-10-15 00:00:00'), Timestamp('2017-10-21 00:00:00'), Timestamp('2017-10-22 00:00:00')] ...
#   Overlap days: 1329
#
# CVX (chevron):
#   Finance rows: 1510
#   Sentiment rows: 2153
#   Days in finance but missing in sentiment: 25
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 668
#     Extra days: [Timestamp('2017-02-11 00:00:00'), Timestamp('2017-02-12 00:00:00'), Timestamp('2017-02-18 00:00:00'), Timestamp('2017-02-19 00:00:00'), Timestamp('2017-02-20 00:00:00'), Timestamp('2017-02-25 00:00:00'), Timestamp('2017-02-26 00:00:00'), Timestamp('2017-03-04 00:00:00'), Timestamp('2017-03-05 00:00:00'), Timestamp('2017-03-11 00:00:00')] ...
#   Overlap days: 1485
#
# DIS (disney):
#   Finance rows: 1510
#   Sentiment rows: 2180
#   Days in finance but missing in sentiment: 7
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00')]
#   Days in sentiment but not in finance: 677
#     Extra days: [Timestamp('2017-01-14 00:00:00'), Timestamp('2017-01-15 00:00:00'), Timestamp('2017-01-16 00:00:00'), Timestamp('2017-01-21 00:00:00'), Timestamp('2017-01-22 00:00:00'), Timestamp('2017-01-28 00:00:00'), Timestamp('2017-01-29 00:00:00'), Timestamp('2017-02-04 00:00:00'), Timestamp('2017-02-05 00:00:00'), Timestamp('2017-02-11 00:00:00')] ...
#   Overlap days: 1503
#
# GS (goldman):
#   Finance rows: 1510
#   Sentiment rows: 2002
#   Days in finance but missing in sentiment: 130
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 622
#     Extra days: [Timestamp('2017-02-11 00:00:00'), Timestamp('2017-02-12 00:00:00'), Timestamp('2017-02-18 00:00:00'), Timestamp('2017-02-19 00:00:00'), Timestamp('2017-02-20 00:00:00'), Timestamp('2017-02-25 00:00:00'), Timestamp('2017-02-26 00:00:00'), Timestamp('2017-03-04 00:00:00'), Timestamp('2017-03-05 00:00:00'), Timestamp('2017-03-11 00:00:00')] ...
#   Overlap days: 1380
#
# HD (home):
#   Finance rows: 1510
#   Sentiment rows: 2147
#   Days in finance but missing in sentiment: 29
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 666
#     Extra days: [Timestamp('2017-02-18 00:00:00'), Timestamp('2017-02-19 00:00:00'), Timestamp('2017-02-20 00:00:00'), Timestamp('2017-02-25 00:00:00'), Timestamp('2017-02-26 00:00:00'), Timestamp('2017-03-04 00:00:00'), Timestamp('2017-03-05 00:00:00'), Timestamp('2017-03-11 00:00:00'), Timestamp('2017-03-12 00:00:00'), Timestamp('2017-03-18 00:00:00')] ...
#   Overlap days: 1481
#
# IBM (ibm):
#   Finance rows: 1510
#   Sentiment rows: 2188
#   Days in finance but missing in sentiment: 1
#     Missing days: [Timestamp('2017-01-03 00:00:00')]
#   Days in sentiment but not in finance: 679
#     Extra days: [Timestamp('2017-01-07 00:00:00'), Timestamp('2017-01-08 00:00:00'), Timestamp('2017-01-14 00:00:00'), Timestamp('2017-01-15 00:00:00'), Timestamp('2017-01-16 00:00:00'), Timestamp('2017-01-21 00:00:00'), Timestamp('2017-01-22 00:00:00'), Timestamp('2017-01-28 00:00:00'), Timestamp('2017-01-29 00:00:00'), Timestamp('2017-02-04 00:00:00')] ...
#   Overlap days: 1509
#
# JPM (jpmorgan):
#   Finance rows: 1510
#   Sentiment rows: 2153
#   Days in finance but missing in sentiment: 25
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 668
#     Extra days: [Timestamp('2017-02-11 00:00:00'), Timestamp('2017-02-12 00:00:00'), Timestamp('2017-02-18 00:00:00'), Timestamp('2017-02-19 00:00:00'), Timestamp('2017-02-20 00:00:00'), Timestamp('2017-02-25 00:00:00'), Timestamp('2017-02-26 00:00:00'), Timestamp('2017-03-04 00:00:00'), Timestamp('2017-03-05 00:00:00'), Timestamp('2017-03-11 00:00:00')] ...
#   Overlap days: 1485
#
# MCD (mcdonald's):
#   Finance rows: 1510
#   Sentiment rows: 2175
#   Days in finance but missing in sentiment: 9
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00')]
#   Days in sentiment but not in finance: 674
#     Extra days: [Timestamp('2017-01-21 00:00:00'), Timestamp('2017-01-22 00:00:00'), Timestamp('2017-01-28 00:00:00'), Timestamp('2017-01-29 00:00:00'), Timestamp('2017-02-04 00:00:00'), Timestamp('2017-02-05 00:00:00'), Timestamp('2017-02-11 00:00:00'), Timestamp('2017-02-12 00:00:00'), Timestamp('2017-02-18 00:00:00'), Timestamp('2017-02-19 00:00:00')] ...
#   Overlap days: 1501
#
# MMM (3m):
#   Finance rows: 1510
#   Sentiment rows: 2124
#   Days in finance but missing in sentiment: 45
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 659
#     Extra days: [Timestamp('2017-03-11 00:00:00'), Timestamp('2017-03-12 00:00:00'), Timestamp('2017-03-18 00:00:00'), Timestamp('2017-03-19 00:00:00'), Timestamp('2017-03-25 00:00:00'), Timestamp('2017-03-26 00:00:00'), Timestamp('2017-04-01 00:00:00'), Timestamp('2017-04-02 00:00:00'), Timestamp('2017-04-08 00:00:00'), Timestamp('2017-04-09 00:00:00')] ...
#   Overlap days: 1465
#
# MSFT (microsoft):
#   Finance rows: 1510
#   Sentiment rows: 2147
#   Days in finance but missing in sentiment: 29
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 666
#     Extra days: [Timestamp('2017-02-18 00:00:00'), Timestamp('2017-02-19 00:00:00'), Timestamp('2017-02-20 00:00:00'), Timestamp('2017-02-25 00:00:00'), Timestamp('2017-02-26 00:00:00'), Timestamp('2017-03-04 00:00:00'), Timestamp('2017-03-05 00:00:00'), Timestamp('2017-03-11 00:00:00'), Timestamp('2017-03-12 00:00:00'), Timestamp('2017-03-18 00:00:00')] ...
#   Overlap days: 1481
#
# NKE (nike):
#   Finance rows: 1510
#   Sentiment rows: 2173
#   Days in finance but missing in sentiment: 11
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 674
#     Extra days: [Timestamp('2017-01-21 00:00:00'), Timestamp('2017-01-22 00:00:00'), Timestamp('2017-01-28 00:00:00'), Timestamp('2017-01-29 00:00:00'), Timestamp('2017-02-04 00:00:00'), Timestamp('2017-02-05 00:00:00'), Timestamp('2017-02-11 00:00:00'), Timestamp('2017-02-12 00:00:00'), Timestamp('2017-02-18 00:00:00'), Timestamp('2017-02-19 00:00:00')] ...
#   Overlap days: 1499
#
# TRV (travelers):
#   Finance rows: 1510
#   Sentiment rows: 2112
#   Days in finance but missing in sentiment: 53
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 655
#     Extra days: [Timestamp('2017-03-25 00:00:00'), Timestamp('2017-03-26 00:00:00'), Timestamp('2017-04-01 00:00:00'), Timestamp('2017-04-02 00:00:00'), Timestamp('2017-04-08 00:00:00'), Timestamp('2017-04-09 00:00:00'), Timestamp('2017-04-14 00:00:00'), Timestamp('2017-04-15 00:00:00'), Timestamp('2017-04-16 00:00:00'), Timestamp('2017-04-22 00:00:00')] ...
#   Overlap days: 1457
#
# UNH (unitedhealth):
#   Finance rows: 1510
#   Sentiment rows: 2144
#   Days in finance but missing in sentiment: 32
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 666
#     Extra days: [Timestamp('2017-02-18 00:00:00'), Timestamp('2017-02-19 00:00:00'), Timestamp('2017-02-20 00:00:00'), Timestamp('2017-02-25 00:00:00'), Timestamp('2017-02-26 00:00:00'), Timestamp('2017-03-04 00:00:00'), Timestamp('2017-03-05 00:00:00'), Timestamp('2017-03-11 00:00:00'), Timestamp('2017-03-12 00:00:00'), Timestamp('2017-03-18 00:00:00')] ...
#   Overlap days: 1478
#
# VZ (verizon):
#   Finance rows: 1510
#   Sentiment rows: 2166
#   Days in finance but missing in sentiment: 16
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 672
#     Extra days: [Timestamp('2017-01-28 00:00:00'), Timestamp('2017-01-29 00:00:00'), Timestamp('2017-02-04 00:00:00'), Timestamp('2017-02-05 00:00:00'), Timestamp('2017-02-11 00:00:00'), Timestamp('2017-02-12 00:00:00'), Timestamp('2017-02-18 00:00:00'), Timestamp('2017-02-19 00:00:00'), Timestamp('2017-02-20 00:00:00'), Timestamp('2017-02-25 00:00:00')] ...
#   Overlap days: 1494
#
# V (visa):
#   Finance rows: 1510
#   Sentiment rows: 2176
#   Days in finance but missing in sentiment: 9
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00')]
#   Days in sentiment but not in finance: 675
#     Extra days: [Timestamp('2017-01-16 00:00:00'), Timestamp('2017-01-21 00:00:00'), Timestamp('2017-01-22 00:00:00'), Timestamp('2017-01-28 00:00:00'), Timestamp('2017-01-29 00:00:00'), Timestamp('2017-02-04 00:00:00'), Timestamp('2017-02-05 00:00:00'), Timestamp('2017-02-11 00:00:00'), Timestamp('2017-02-12 00:00:00'), Timestamp('2017-02-18 00:00:00')] ...
#   Overlap days: 1501
#
# WMT (walmart):
#   Finance rows: 1510
#   Sentiment rows: 2185
#   Days in finance but missing in sentiment: 4
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00')]
#   Days in sentiment but not in finance: 679
#     Extra days: [Timestamp('2017-01-07 00:00:00'), Timestamp('2017-01-08 00:00:00'), Timestamp('2017-01-14 00:00:00'), Timestamp('2017-01-15 00:00:00'), Timestamp('2017-01-16 00:00:00'), Timestamp('2017-01-21 00:00:00'), Timestamp('2017-01-22 00:00:00'), Timestamp('2017-01-28 00:00:00'), Timestamp('2017-01-29 00:00:00'), Timestamp('2017-02-04 00:00:00')] ...
#   Overlap days: 1506
#
# MCD (mcdonald's):
#   Finance rows: 1510
#   Sentiment rows: 2175
#   Days in finance but missing in sentiment: 9
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00')]
#   Days in sentiment but not in finance: 674
#     Extra days: [Timestamp('2017-01-21 00:00:00'), Timestamp('2017-01-22 00:00:00'), Timestamp('2017-01-28 00:00:00'), Timestamp('2017-01-29 00:00:00'), Timestamp('2017-02-04 00:00:00'), Timestamp('2017-02-05 00:00:00'), Timestamp('2017-02-11 00:00:00'), Timestamp('2017-02-12 00:00:00'), Timestamp('2017-02-18 00:00:00'), Timestamp('2017-02-19 00:00:00')] ...
#   Overlap days: 1501
#
# MMM (3m):
#   Finance rows: 1510
#   Sentiment rows: 2124
#   Days in finance but missing in sentiment: 45
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 659
#     Extra days: [Timestamp('2017-03-11 00:00:00'), Timestamp('2017-03-12 00:00:00'), Timestamp('2017-03-18 00:00:00'), Timestamp('2017-03-19 00:00:00'), Timestamp('2017-03-25 00:00:00'), Timestamp('2017-03-26 00:00:00'), Timestamp('2017-04-01 00:00:00'), Timestamp('2017-04-02 00:00:00'), Timestamp('2017-04-08 00:00:00'), Timestamp('2017-04-09 00:00:00')] ...
#   Overlap days: 1465
#
# MSFT (microsoft):
#   Finance rows: 1510
#   Sentiment rows: 2147
#   Days in finance but missing in sentiment: 29
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 666
#     Extra days: [Timestamp('2017-02-18 00:00:00'), Timestamp('2017-02-19 00:00:00'), Timestamp('2017-02-20 00:00:00'), Timestamp('2017-02-25 00:00:00'), Timestamp('2017-02-26 00:00:00'), Timestamp('2017-03-04 00:00:00'), Timestamp('2017-03-05 00:00:00'), Timestamp('2017-03-11 00:00:00'), Timestamp('2017-03-12 00:00:00'), Timestamp('2017-03-18 00:00:00')] ...
#   Overlap days: 1481
#
# NKE (nike):
#   Finance rows: 1510
#   Sentiment rows: 2173
#   Days in finance but missing in sentiment: 11
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 674
#     Extra days: [Timestamp('2017-01-21 00:00:00'), Timestamp('2017-01-22 00:00:00'), Timestamp('2017-01-28 00:00:00'), Timestamp('2017-01-29 00:00:00'), Timestamp('2017-02-04 00:00:00'), Timestamp('2017-02-05 00:00:00'), Timestamp('2017-02-11 00:00:00'), Timestamp('2017-02-12 00:00:00'), Timestamp('2017-02-18 00:00:00'), Timestamp('2017-02-19 00:00:00')] ...
#   Overlap days: 1499
#
# TRV (travelers):
#   Finance rows: 1510
#   Sentiment rows: 2112
#   Days in finance but missing in sentiment: 53
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 655
#     Extra days: [Timestamp('2017-03-25 00:00:00'), Timestamp('2017-03-26 00:00:00'), Timestamp('2017-04-01 00:00:00'), Timestamp('2017-04-02 00:00:00'), Timestamp('2017-04-08 00:00:00'), Timestamp('2017-04-09 00:00:00'), Timestamp('2017-04-14 00:00:00'), Timestamp('2017-04-15 00:00:00'), Timestamp('2017-04-16 00:00:00'), Timestamp('2017-04-22 00:00:00')] ...
#   Overlap days: 1457
#
# UNH (unitedhealth):
#   Finance rows: 1510
#   Sentiment rows: 2144
#   Days in finance but missing in sentiment: 32
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 666
#     Extra days: [Timestamp('2017-02-18 00:00:00'), Timestamp('2017-02-19 00:00:00'), Timestamp('2017-02-20 00:00:00'), Timestamp('2017-02-25 00:00:00'), Timestamp('2017-02-26 00:00:00'), Timestamp('2017-03-04 00:00:00'), Timestamp('2017-03-05 00:00:00'), Timestamp('2017-03-11 00:00:00'), Timestamp('2017-03-12 00:00:00'), Timestamp('2017-03-18 00:00:00')] ...
#   Overlap days: 1478
#
# VZ (verizon):
#   Finance rows: 1510
#   Sentiment rows: 2166
#   Days in finance but missing in sentiment: 16
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00'), Timestamp('2017-01-17 00:00:00')] ...
#   Days in sentiment but not in finance: 672
#     Extra days: [Timestamp('2017-01-28 00:00:00'), Timestamp('2017-01-29 00:00:00'), Timestamp('2017-02-04 00:00:00'), Timestamp('2017-02-05 00:00:00'), Timestamp('2017-02-11 00:00:00'), Timestamp('2017-02-12 00:00:00'), Timestamp('2017-02-18 00:00:00'), Timestamp('2017-02-19 00:00:00'), Timestamp('2017-02-20 00:00:00'), Timestamp('2017-02-25 00:00:00')] ...
#   Overlap days: 1494
#
# V (visa):
#   Finance rows: 1510
#   Sentiment rows: 2176
#   Days in finance but missing in sentiment: 9
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00'), Timestamp('2017-01-09 00:00:00'), Timestamp('2017-01-10 00:00:00'), Timestamp('2017-01-11 00:00:00'), Timestamp('2017-01-12 00:00:00'), Timestamp('2017-01-13 00:00:00')]
#   Days in sentiment but not in finance: 675
#     Extra days: [Timestamp('2017-01-16 00:00:00'), Timestamp('2017-01-21 00:00:00'), Timestamp('2017-01-22 00:00:00'), Timestamp('2017-01-28 00:00:00'), Timestamp('2017-01-29 00:00:00'), Timestamp('2017-02-04 00:00:00'), Timestamp('2017-02-05 00:00:00'), Timestamp('2017-02-11 00:00:00'), Timestamp('2017-02-12 00:00:00'), Timestamp('2017-02-18 00:00:00')] ...
#   Overlap days: 1501
#
# WMT (walmart):
#   Finance rows: 1510
#   Sentiment rows: 2185
#   Days in finance but missing in sentiment: 4
#     Missing days: [Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00')]
#   Days in sentiment but not in finance: 679
#     Extra days: [Timestamp('2017-01-07 00:00:00'), Timestamp('2017-01-08 00:00:00'), Timestamp('2017-01-14 00:00:00'), Timestamp('2017-01-15 00:00:00'), Timestamp('2017-01-16 00:00:00'), Timestamp('2017-01-21 00:00:00'), Timestamp('2017-01-22 00:00:00'), Timestamp('2017-01-28 00:00:00'), Timestamp('2017-01-29 00:00:00'), Timestamp('2017-02-04 00:00:00')] ...
#   Overlap days: 1506

# %%
from collections import Counter

# Consolidate sentiment-only days (e.g., weekends) to the next available finance day
# and count how many days are consolidated


# Sort the sets for ordered processing
missing_in_fin_sorted = sorted(missing_in_fin)
fin_dates_sorted = sorted(fin_dates_set)

# Build a lookup for the next available finance day
consolidation_map = {}
consolidated_count = 0

for sent_day in missing_in_fin_sorted:
    # Find the next finance day after the sentiment-only day
    next_fin_days = [d for d in fin_dates_sorted if d > sent_day]
    if next_fin_days:
        next_fin_day = next_fin_days[0]
        consolidation_map[sent_day] = next_fin_day
        consolidated_count += 1

print(f"Total sentiment-only days consolidated to next finance day: {consolidated_count}")
# Optionally, show a few examples
print("First 10 consolidated days (sentiment day -> next finance day):")
for i, (k, v) in enumerate(consolidation_map.items()):
    if i >= 10:
        break
    print(f"{k.date()} -> {v.date()}")
# Out:
# Total sentiment-only days consolidated to next finance day: 54
# First 10 consolidated days (sentiment day -> next finance day):
# 2017-01-16 -> 2017-01-17
# 2017-02-20 -> 2017-02-21
# 2017-04-14 -> 2017-04-17
# 2017-05-29 -> 2017-05-30
# 2017-07-04 -> 2017-07-05
# 2017-09-04 -> 2017-09-05
# 2017-11-23 -> 2017-11-24
# 2017-12-25 -> 2017-12-26
# 2018-01-01 -> 2018-01-02
# 2018-01-15 -> 2018-01-16
